# %%
import os
from matplotlib import pyplot as plt

# %%
class BasicDataVisualizer:
    x = []
    y = []
    
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    def plot(self):
        plt.plot(self.x, self.y)
        plt.show()

# %%
# Dummy Data
x = [1,2,3,4,5]
y = [50,40,30,20,100]

# %%
dataVisualizer = BasicDataVisualizer(x,y)

# %%
dataVisualizer.plot()

# %%
import json

class JsonDataVisualizer(BasicDataVisualizer):
    x = []
    y = []
    
    def __init__(self, jsonFileName):
        f = open(jsonFileName)
        jsonData = json.load(f)
        x = []
        y = []
        for datum in jsonData['data']:
            x.append(datum["x"])
            y.append(datum["y"])
        
        super().__init__(x, y)
        f.close()

# %%
jsonDataVisualizer = JsonDataVisualizer("sample.json")

# %%
jsonDataVisualizer.plot()

# %% [markdown]
# ## Exercise I: Write a CSV Data Visualizer

# %%
import csv

class CSVDataVisualizer(BasicDataVisualizer):
    x = []
    y = []
    
    def __init__(self, csvFile):
        # Finish this function
        f = open(csvFile)
        csvData = csv.reader(f, delimiter = ',')
        header = next(f)
        x = []
        y = []
        for datum in csvData:
            x.append(datum[0])
            y.append(int(datum[1]))
        
        super().__init__(x, y)
        f.close()

# %%
csvDataVisualizer = CSVDataVisualizer("sample.csv")
csvDataVisualizer.plot()

# %% [markdown]
# ## Exercise II:
# #### Extend DataVisualizer such that it can be configured to plot bar graphs, line graphs, scatter plots

# %%
class AdvancedDataVisualizer(BasicDataVisualizer):
    
    def __init__(self, x, y, barType):
        # finish this function
        data = {1:10, 2:2, 3:3, 4:4}
        if barType == "bar":
            x = list(data.keys()) 
            y = list(data.values())
            plt.bar(x, y)
        if barType == "scatter":
            x = list(data.keys()) 
            y = list(data.values())
            plt.scatter(x, y)            
                
    def plot(self):
        # # finish this function // not very sure on how to split the solution into this function
        pass

# %% [markdown]
# ## Expected outputs

# %%
dataVisualizer = AdvancedDataVisualizer(x, y, "bar")
dataVisualizer.plot()

# %%
dataVisualizer = AdvancedDataVisualizer(x, y, "scatter")
dataVisualizer.plot()
